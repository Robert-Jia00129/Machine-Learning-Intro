# %%
# Import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
np.random.seed(0)
tf.random.set_seed(0)
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers
from tensorflow.keras.models import load_model
from tensorflow.keras import regularizers
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from helper import unregularized_model
# %matplotlib inline

# %% [markdown]
# ## Implement an unregularized NN

# %%
# Call the helper function to get the unregularized model along with the data
x_b, x_train, x_test, y_train, y_test, y_pred, mse = unregularized_model()

# %%
# Printing the MSE of the unregularized model
print("MSE of the unregularized model is", mse)
# Out:
# MSE of the unregularized model is 1.1089915570703672

# %% [markdown]
# ### ⏸ Based on the trace plot, which patience value would you most likely choose?
#
#
# #### A. 1
# #### B. 5-10
# #### C. 45-50
# #### D. 50-75

# %%
### edTest(test_chow1) ###
# Submit an answer choice as a string below (eg. if you choose option A, put 'A')
answer1 = 'B'

# %% [markdown]
# ## Implement previous NN with early stopping
# For early stopping we build the same network but then we implement early stopping using callbacks.

# %%
# Building an unregularized NN with early stopping. 
# Initialise the NN, give it an appropriate name for the ease of reading
# The FCNN has 5 layers, each with 100 nodes
model_2 = models.Sequential(name='EarlyStopping')

# Add 5 hidden layers with 100 neurons each 
# tanh is the activation for the first layer
# relu is the activation for all other layers
model_2.add(layers.Dense(100,  activation='tanh', input_shape=(1,)))
model_2.add(layers.Dense(100,  activation='ReLU'))
model_2.add(layers.Dense(100,  activation='ReLU'))
model_2.add(layers.Dense(100,  activation='ReLU'))
model_2.add(layers.Dense(100,  activation='ReLU'))

# Add the output layer with one neuron 
model_2.add(layers.Dense(1,  activation='linear'))

# View the model summary
model_2.summary()
# Out:
# Model: "EarlyStopping"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 100)               200
#
#  dense_19 (Dense)            (None, 100)               10100
#
#  dense_20 (Dense)            (None, 100)               10100
#
#  dense_21 (Dense)            (None, 100)               10100
#
#  dense_22 (Dense)            (None, 100)               10100
#
#  dense_23 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 40,701
# Trainable params: 40,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Use the keras early stopping callback with the patience value of your choosing 
# while monitoring the val_loss
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=100,restore_best_weights=True)

# Compile the model with MSE as loss 
# and Adam optimizer with learning rate as 0.001
opt = tf.keras.optimizers.Adam(lr=0.001)
model_2.compile(optimizer=opt,loss='mean_squared_error',metrics=['mean_squared_error'])

# Save the history about the model after fitting on the train data
# Use 0.2 validation split with 1500 epochs and batch size of 10
# Use the callback for early stopping here
history_2 = model_2.fit(x=x_train,y=y_train,batch_size=10,epochs=1500,validation_split=0.2,callbacks=callback)
# Out:
# Epoch 1/1500
# 2/2 [==============================] - 1s 475ms/step - loss: 2.6028 - mean_squared_error: 2.6028 - val_loss: 0.4090 - val_mean_squared_error: 0.4090
# Epoch 2/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 2.0431 - mean_squared_error: 2.0431 - val_loss: 0.5087 - val_mean_squared_error: 0.5087
# Epoch 3/1500
# 2/2 [==============================] - 0s 27ms/step - loss: 2.1095 - mean_squared_error: 2.1095 - val_loss: 0.5148 - val_mean_squared_error: 0.5148
# Epoch 4/1500
# 2/2 [==============================] - 0s 35ms/step - loss: 2.0856 - mean_squared_error: 2.0856 - val_loss: 0.2121 - val_mean_squared_error: 0.2121
# Epoch 5/1500
# 2/2 [==============================] - 0s 33ms/step - loss: 1.5641 - mean_squared_error: 1.5641 - val_loss: 0.0676 - val_mean_squared_error: 0.0676
# Epoch 6/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 1.3007 - mean_squared_error: 1.3007 - val_loss: 0.7636 - val_mean_squared_error: 0.7636
# Epoch 7/1500
# 2/2 [==============================] - 0s 34ms/step - loss: 1.9006 - mean_squared_error: 1.9006 - val_loss: 0.8554 - val_mean_squared_error: 0.8554
# Epoch 8/1500
# 2/2 [==============================] - 0s 27ms/step - loss: 1.5510 - mean_squared_error: 1.5510 - val_loss: 0.1297 - val_mean_squared_error: 0.1297
# Epoch 9/1500
# 2/2 [==============================] - 0s 27ms/step - loss: 1.1370 - mean_squared_error: 1.1370 - val_loss: 0.1240 - val_mean_squared_error: 0.1240
# Epoch 10/1500
# 2/2 [==============================] - 0s 26ms/step - loss: 1.9068 - mean_squared_error: 1.9068 - val_loss: 0.3029 - val_mean_squared_error: 0.3029
# Epoch 11/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 1.7474 - mean_squared_error: 1.7474 - val_loss: 0.0785 - val_mean_squared_error: 0.0785
# Epoch 12/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 1.5006 - mean_squared_error: 1.5006 - val_loss: 0.2005 - val_mean_squared_error: 0.2005
# Epoch 13/1500
# 2/2 [==============================] - 0s 33ms/step - loss: 1.1998 - mean_squared_error: 1.1998 - val_loss: 0.6492 - val_mean_squared_error: 0.6492
# Epoch 14/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 1.4470 - mean_squared_error: 1.4470 - val_loss: 0.6545 - val_mean_squared_error: 0.6545
# Epoch 15/1500
# 2/2 [==============================] - 0s 31ms/step - loss: 1.3796 - mean_squared_error: 1.3796 - val_loss: 0.2222 - val_mean_squared_error: 0.2222
# Epoch 16/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 1.4437 - mean_squared_error: 1.4437 - val_loss: 0.0290 - val_mean_squared_error: 0.0290
# Epoch 17/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 1.3331 - mean_squared_error: 1.3331 - val_loss: 0.0318 - val_mean_squared_error: 0.0318
# Epoch 18/1500
# 2/2 [==============================] - 0s 27ms/step - loss: 1.3202 - mean_squared_error: 1.3202 - val_loss: 0.0642 - val_mean_squared_error: 0.0642
# Epoch 19/1500
# 2/2 [==============================] - 0s 27ms/step - loss: 1.1612 - mean_squared_error: 1.1612 - val_loss: 0.2459 - val_mean_squared_error: 0.2459
# Epoch 20/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 1.1990 - mean_squared_error: 1.1990 - val_loss: 0.3866 - val_mean_squared_error: 0.3866
# Epoch 21/1500
# 2/2 [==============================] - 0s 27ms/step - loss: 1.2314 - mean_squared_error: 1.2314 - val_loss: 0.2439 - val_mean_squared_error: 0.2439
# Epoch 22/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 1.2188 - mean_squared_error: 1.2188 - val_loss: 0.0737 - val_mean_squared_error: 0.0737
# Epoch 23/1500
# 2/2 [==============================] - 0s 44ms/step - loss: 1.1635 - mean_squared_error: 1.1635 - val_loss: 0.0735 - val_mean_squared_error: 0.0735
# Epoch 24/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 1.1154 - mean_squared_error: 1.1154 - val_loss: 0.0585 - val_mean_squared_error: 0.0585
# Epoch 25/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 1.1219 - mean_squared_error: 1.1219 - val_loss: 0.0858 - val_mean_squared_error: 0.0858
# Epoch 26/1500
# 2/2 [==============================] - 0s 27ms/step - loss: 1.2271 - mean_squared_error: 1.2271 - val_loss: 0.1458 - val_mean_squared_error: 0.1458
# Epoch 27/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 1.1723 - mean_squared_error: 1.1723 - val_loss: 0.0611 - val_mean_squared_error: 0.0611
# Epoch 28/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 1.1323 - mean_squared_error: 1.1323 - val_loss: 0.1241 - val_mean_squared_error: 0.1241
# Epoch 29/1500
# 2/2 [==============================] - 0s 34ms/step - loss: 1.1012 - mean_squared_error: 1.1012 - val_loss: 0.1258 - val_mean_squared_error: 0.1258
# Epoch 30/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 1.0517 - mean_squared_error: 1.0517 - val_loss: 0.0818 - val_mean_squared_error: 0.0818
# Epoch 31/1500
# 2/2 [==============================] - 0s 35ms/step - loss: 1.0833 - mean_squared_error: 1.0833 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 32/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 1.0394 - mean_squared_error: 1.0394 - val_loss: 0.2564 - val_mean_squared_error: 0.2564
# Epoch 33/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 1.0592 - mean_squared_error: 1.0592 - val_loss: 0.2677 - val_mean_squared_error: 0.2677
# Epoch 34/1500
# 2/2 [==============================] - 0s 39ms/step - loss: 1.1224 - mean_squared_error: 1.1224 - val_loss: 0.1709 - val_mean_squared_error: 0.1709
# Epoch 35/1500
# 2/2 [==============================] - 0s 31ms/step - loss: 1.0242 - mean_squared_error: 1.0242 - val_loss: 0.2039 - val_mean_squared_error: 0.2039
# Epoch 36/1500
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0271 - mean_squared_error: 1.0271 - val_loss: 0.1583 - val_mean_squared_error: 0.1583
# Epoch 37/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 1.0205 - mean_squared_error: 1.0205 - val_loss: 0.1625 - val_mean_squared_error: 0.1625
# Epoch 38/1500
# 2/2 [==============================] - 0s 31ms/step - loss: 1.0118 - mean_squared_error: 1.0118 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 39/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 1.0119 - mean_squared_error: 1.0119 - val_loss: 0.1593 - val_mean_squared_error: 0.1593
# Epoch 40/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 1.0286 - mean_squared_error: 1.0286 - val_loss: 0.1901 - val_mean_squared_error: 0.1901
# Epoch 41/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.9897 - mean_squared_error: 0.9897 - val_loss: 0.1132 - val_mean_squared_error: 0.1132
# Epoch 42/1500
# 2/2 [==============================] - 0s 36ms/step - loss: 1.0039 - mean_squared_error: 1.0039 - val_loss: 0.1226 - val_mean_squared_error: 0.1226
# Epoch 43/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 1.0490 - mean_squared_error: 1.0490 - val_loss: 0.1654 - val_mean_squared_error: 0.1654
# Epoch 44/1500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9711 - mean_squared_error: 0.9711 - val_loss: 0.1393 - val_mean_squared_error: 0.1393
# Epoch 45/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.9606 - mean_squared_error: 0.9606 - val_loss: 0.2053 - val_mean_squared_error: 0.2053
# Epoch 46/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.9933 - mean_squared_error: 0.9933 - val_loss: 0.1868 - val_mean_squared_error: 0.1868
# Epoch 47/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.9492 - mean_squared_error: 0.9492 - val_loss: 0.1110 - val_mean_squared_error: 0.1110
# Epoch 48/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.9940 - mean_squared_error: 0.9940 - val_loss: 0.1451 - val_mean_squared_error: 0.1451
# Epoch 49/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 1.0588 - mean_squared_error: 1.0588 - val_loss: 0.2151 - val_mean_squared_error: 0.2151
# Epoch 50/1500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.9144 - mean_squared_error: 0.9144 - val_loss: 0.1479 - val_mean_squared_error: 0.1479
# Epoch 51/1500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9572 - mean_squared_error: 0.9572 - val_loss: 0.1705 - val_mean_squared_error: 0.1705
# Epoch 52/1500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.9661 - mean_squared_error: 0.9661 - val_loss: 0.3155 - val_mean_squared_error: 0.3155
# Epoch 53/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.9399 - mean_squared_error: 0.9399 - val_loss: 0.1885 - val_mean_squared_error: 0.1885
# Epoch 54/1500
# 2/2 [==============================] - 0s 46ms/step - loss: 1.0019 - mean_squared_error: 1.0019 - val_loss: 0.1602 - val_mean_squared_error: 0.1602
# Epoch 55/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.9585 - mean_squared_error: 0.9585 - val_loss: 0.2552 - val_mean_squared_error: 0.2552
# Epoch 56/1500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.8679 - mean_squared_error: 0.8679 - val_loss: 0.6269 - val_mean_squared_error: 0.6269
# Epoch 57/1500
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0626 - mean_squared_error: 1.0626 - val_loss: 0.4066 - val_mean_squared_error: 0.4066
# Epoch 58/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.9711 - mean_squared_error: 0.9711 - val_loss: 0.2269 - val_mean_squared_error: 0.2269
# Epoch 59/1500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9531 - mean_squared_error: 0.9531 - val_loss: 0.2241 - val_mean_squared_error: 0.2241
# Epoch 60/1500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.9201 - mean_squared_error: 0.9201 - val_loss: 0.3575 - val_mean_squared_error: 0.3575
# Epoch 61/1500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8938 - mean_squared_error: 0.8938 - val_loss: 0.3443 - val_mean_squared_error: 0.3443
# Epoch 62/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8565 - mean_squared_error: 0.8565 - val_loss: 0.2503 - val_mean_squared_error: 0.2503
# Epoch 63/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.8709 - mean_squared_error: 0.8709 - val_loss: 0.2963 - val_mean_squared_error: 0.2963
# Epoch 64/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8525 - mean_squared_error: 0.8525 - val_loss: 0.5174 - val_mean_squared_error: 0.5174
# Epoch 65/1500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.9050 - mean_squared_error: 0.9050 - val_loss: 0.3933 - val_mean_squared_error: 0.3933
# Epoch 66/1500
# 2/2 [==============================] - 0s 26ms/step - loss: 0.8892 - mean_squared_error: 0.8892 - val_loss: 0.2988 - val_mean_squared_error: 0.2988
# Epoch 67/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.9014 - mean_squared_error: 0.9014 - val_loss: 0.3985 - val_mean_squared_error: 0.3985
# Epoch 68/1500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.8259 - mean_squared_error: 0.8259 - val_loss: 0.3971 - val_mean_squared_error: 0.3971
# Epoch 69/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.8228 - mean_squared_error: 0.8228 - val_loss: 0.4397 - val_mean_squared_error: 0.4397
# Epoch 70/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.9507 - mean_squared_error: 0.9507 - val_loss: 0.3166 - val_mean_squared_error: 0.3166
# Epoch 71/1500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8453 - mean_squared_error: 0.8453 - val_loss: 0.3040 - val_mean_squared_error: 0.3040
# Epoch 72/1500
# 2/2 [==============================] - 0s 49ms/step - loss: 1.0774 - mean_squared_error: 1.0774 - val_loss: 0.3110 - val_mean_squared_error: 0.3110
# Epoch 73/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 1.0081 - mean_squared_error: 1.0081 - val_loss: 0.5337 - val_mean_squared_error: 0.5337
# Epoch 74/1500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.8722 - mean_squared_error: 0.8722 - val_loss: 0.4078 - val_mean_squared_error: 0.4078
# Epoch 75/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.9978 - mean_squared_error: 0.9978 - val_loss: 0.3528 - val_mean_squared_error: 0.3528
# Epoch 76/1500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8005 - mean_squared_error: 0.8005 - val_loss: 0.7581 - val_mean_squared_error: 0.7581
# Epoch 77/1500
# 2/2 [==============================] - 0s 41ms/step - loss: 0.9119 - mean_squared_error: 0.9119 - val_loss: 0.7067 - val_mean_squared_error: 0.7067
# Epoch 78/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.9014 - mean_squared_error: 0.9014 - val_loss: 0.3967 - val_mean_squared_error: 0.3967
# Epoch 79/1500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8247 - mean_squared_error: 0.8247 - val_loss: 0.3984 - val_mean_squared_error: 0.3984
# Epoch 80/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8294 - mean_squared_error: 0.8294 - val_loss: 0.4786 - val_mean_squared_error: 0.4786
# Epoch 81/1500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8276 - mean_squared_error: 0.8276 - val_loss: 0.5702 - val_mean_squared_error: 0.5702
# Epoch 82/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8693 - mean_squared_error: 0.8693 - val_loss: 0.4742 - val_mean_squared_error: 0.4742
# Epoch 83/1500
# 2/2 [==============================] - 0s 38ms/step - loss: 0.8620 - mean_squared_error: 0.8620 - val_loss: 0.4248 - val_mean_squared_error: 0.4248
# Epoch 84/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7989 - mean_squared_error: 0.7989 - val_loss: 0.5963 - val_mean_squared_error: 0.5963
# Epoch 85/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7932 - mean_squared_error: 0.7932 - val_loss: 0.8094 - val_mean_squared_error: 0.8094
# Epoch 86/1500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.8390 - mean_squared_error: 0.8390 - val_loss: 0.5560 - val_mean_squared_error: 0.5560
# Epoch 87/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.7596 - mean_squared_error: 0.7596 - val_loss: 0.4950 - val_mean_squared_error: 0.4950
# Epoch 88/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7926 - mean_squared_error: 0.7926 - val_loss: 0.5109 - val_mean_squared_error: 0.5109
# Epoch 89/1500
# 2/2 [==============================] - 0s 34ms/step - loss: 0.8132 - mean_squared_error: 0.8132 - val_loss: 0.6466 - val_mean_squared_error: 0.6466
# Epoch 90/1500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.7598 - mean_squared_error: 0.7598 - val_loss: 0.9026 - val_mean_squared_error: 0.9026
# Epoch 91/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.8031 - mean_squared_error: 0.8031 - val_loss: 0.6184 - val_mean_squared_error: 0.6184
# Epoch 92/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7896 - mean_squared_error: 0.7896 - val_loss: 0.5889 - val_mean_squared_error: 0.5889
# Epoch 93/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7531 - mean_squared_error: 0.7531 - val_loss: 0.7309 - val_mean_squared_error: 0.7309
# Epoch 94/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.7943 - mean_squared_error: 0.7943 - val_loss: 0.6861 - val_mean_squared_error: 0.6861
# Epoch 95/1500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7753 - mean_squared_error: 0.7753 - val_loss: 0.5784 - val_mean_squared_error: 0.5784
# Epoch 96/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.7953 - mean_squared_error: 0.7953 - val_loss: 0.6062 - val_mean_squared_error: 0.6062
# Epoch 97/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.7342 - mean_squared_error: 0.7342 - val_loss: 0.8118 - val_mean_squared_error: 0.8118
# Epoch 98/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7995 - mean_squared_error: 0.7995 - val_loss: 0.7102 - val_mean_squared_error: 0.7102
# Epoch 99/1500
# 2/2 [==============================] - 0s 27ms/step - loss: 0.7285 - mean_squared_error: 0.7285 - val_loss: 0.6073 - val_mean_squared_error: 0.6073
# Epoch 100/1500
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7903 - mean_squared_error: 0.7903 - val_loss: 0.6154 - val_mean_squared_error: 0.6154
# Epoch 101/1500
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7754 - mean_squared_error: 0.7754 - val_loss: 0.7388 - val_mean_squared_error: 0.7388
# Epoch 102/1500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7329 - mean_squared_error: 0.7329 - val_loss: 0.7767 - val_mean_squared_error: 0.7767
# Epoch 103/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7241 - mean_squared_error: 0.7241 - val_loss: 0.7700 - val_mean_squared_error: 0.7700
# Epoch 104/1500
# 2/2 [==============================] - 0s 35ms/step - loss: 0.7432 - mean_squared_error: 0.7432 - val_loss: 0.7677 - val_mean_squared_error: 0.7677
# Epoch 105/1500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7137 - mean_squared_error: 0.7137 - val_loss: 0.8138 - val_mean_squared_error: 0.8138
# Epoch 106/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7233 - mean_squared_error: 0.7233 - val_loss: 0.7954 - val_mean_squared_error: 0.7954
# Epoch 107/1500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7229 - mean_squared_error: 0.7229 - val_loss: 0.7407 - val_mean_squared_error: 0.7407
# Epoch 108/1500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7550 - mean_squared_error: 0.7550 - val_loss: 0.6939 - val_mean_squared_error: 0.6939
# Epoch 109/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7288 - mean_squared_error: 0.7288 - val_loss: 0.7977 - val_mean_squared_error: 0.7977
# Epoch 110/1500
# 2/2 [==============================] - 0s 29ms/step - loss: 0.7560 - mean_squared_error: 0.7560 - val_loss: 0.8965 - val_mean_squared_error: 0.8965
# Epoch 111/1500
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7246 - mean_squared_error: 0.7246 - val_loss: 0.6880 - val_mean_squared_error: 0.6880
# Epoch 112/1500
# 2/2 [==============================] - 0s 30ms/step - loss: 0.7505 - mean_squared_error: 0.7505 - val_loss: 0.6845 - val_mean_squared_error: 0.6845
# Epoch 113/1500
# 2/2 [==============================] - 0s 36ms/step - loss: 0.7794 - mean_squared_error: 0.7794 - val_loss: 0.7670 - val_mean_squared_error: 0.7670
# Epoch 114/1500
# 2/2 [==============================] - 0s 50ms/step - loss: 0.7076 - mean_squared_error: 0.7076 - val_loss: 1.3038 - val_mean_squared_error: 1.3038
# Epoch 115/1500
# 2/2 [==============================] - 0s 28ms/step - loss: 0.9643 - mean_squared_error: 0.9643 - val_loss: 0.7584 - val_mean_squared_error: 0.7584
# Epoch 116/1500
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6907 - mean_squared_error: 0.6907 - val_loss: 0.6729 - val_mean_squared_error: 0.6729

# %%
# Helper code to plot the data
# Plot the MSE of the model
plt.rcParams["figure.figsize"] = (10,8)
plt.title("Early stop model")
plt.semilogy(history_2.history['loss'], label='Train Loss', color='#FF9A98', linewidth=2)
plt.semilogy(history_2.history['val_loss'],  label='Validation Loss', color='#75B594', linewidth=2)
plt.legend()

# Set the axes labels
plt.xlabel('Epochs')
plt.ylabel('Log MSE Loss')
plt.legend()
plt.show()

# %%
### edTest(test_mse) ###
# Use the early stop implemented model above to predict for 
# x_b (used exclusively for plotting)
y_early_stop_pred = model_2.predict(x_b)

# Use the model above to predict on the test data
y_earl_stop_pred_test = model_2.predict(x_test)

# Compute the test MSE by predicting on the test data
mse_es = mean_squared_error(y_test,y_pred=y_earl_stop_pred_test)

# %%
# Print the MSE of the early stopped model
print("MSE of the early stopping regularized model is", mse_es)
# Out:
# MSE of the early stopping regularized model is 1.180136883879896

# %%
# Use the helper code to plot the predicted data

# Plotting the predicted data using the L2 regularized model
plt.rcParams["figure.figsize"] = (10,8)
plt.plot(x_b, y_early_stop_pred, label='Early stop regularized model', color='black', linewidth=2)

# Plotting the predicted data using the unregularized model
plt.plot(x_b, y_pred, label = 'Unregularized model', color='#005493', linewidth=2)

# Plotting the training data
plt.plot(x_train,y_train, '.', label='Train data', markersize=15, color='#FF9A98')

# Plotting the testing data
plt.plot(x_test,y_test, '.', label='Test data', markersize=15, color='#75B594')

# Set the axes labels
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %% [markdown]
# ### ⏸ **After marking, change the patience parameter once to 2 and once to 100 in the early stopping callback with the same data. Do you notice any change? Which value is more efficient?**

# %%
### edTest(test_chow2) ###
# Type your answer within in the quotes given

answer2 = 'Pateince=100 allows more epoch training and yield '
